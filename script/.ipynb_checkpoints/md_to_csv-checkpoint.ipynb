# %% [markdown]
# # Scripts to Generate an Aggregate CSV file from Markdown Files of SDG Indicators Data
#
# ### Written by Myeong Lee (University of Maryland)

# %%
import csv
import re
import collections
import json
import glob
import pandas as pd

file_path = r"../_indicators/"
out_csv = r"aggregate_md.csv"

# %%
parsed_data = {}  
index = 0
df = pd.DataFrame(columns=['title'])
first = True
multi_lines = False

# Looping through a folder with MD files
for txt_file in glob.glob(file_path + "*.md"):
    print (txt_file)

    key = ""
    value = ""
    prev_key = ""


    with open(txt_file) as f:
        for line in f:         
            
            if line.startswith("  "):
                multi_lines = True
                
            line = line.strip()
            line = ' '.join(line.split())
            check = line.split(":",1)     

            if check[0].startswith("--"):
                continue

            if len(check) == 2 and check[0] != "https" and check[0] != "http" and multi_lines == False:
                if prev_key != key and value != "":
                    if key not in df.columns: 
                        df[key] = pd.Series([""], index=df.index)
                        first = False
                    df.loc[index,key]= value
                    prev_key = key
                key = check[0]
                
                if check[1].find(">-") != -1:
                    multi_lines = True
                    
                value = re.sub('>-', '', check[1])   
                value = re.sub("'", '', value)
                value = re.sub('"', '', value)
                value = value.strip()
            else:            
                value = value + " " + re.sub('>-', '', line)
                value = re.sub("'", '', value)
                value = re.sub('"', '', value)
                value = value.strip()
                multi_lines = False


        index += 1
# Out:
# ../_indicators/1-1-1.md
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-cc660b896584> in <module>()
#      27                 continue
#      28
# ---> 29             if len(check) == 2 and check[0] != "https" and check[""] != "http" and multi_lines == False:
#      30                 if prev_key != key and value != "":
#      31                     if key not in df.columns:
#
# TypeError: list indices must be integers, not str

# %%
df.head()
# Out:
#                                                title permalink sdg_goal  \
# 0  Proportion of population below the internation...   /1-1-1/        1
# 1  Proportion of population living below the nati...   /1-2-1/        1
# 2  Proportion of men, women and children of all a...   /1-2-2/        1
# 3  Proportion of population covered by social pro...   /1-3-1/        1
# 4  Proportion of population living in households ...   /1-4-1/        1
#
#       layout indicator               indicator_variable         graph  \
# 0  indicator     1.1.1                             null          null
# 1  indicator     1.2.1  tot_proportion_belownatpov_line  longitudinal
# 2  indicator     1.2.2                pct_below_poverty           NaN
# 3  indicator     1.3.1      pct_pop_20_older_full_insrd  longitudinal
# 4  indicator     1.4.1                             null          null
#
#   graph_title graph_type_description graph_status_notes         ...          \
# 0        null                   null               Hold         ...
# 1         NaN             Line graph            Graphed         ...
# 2         NaN                    unk                unk         ...
# 3         NaN                   null   Graphed FIX AXIS         ...
# 4        null                   null                unk         ...
#
#                                           source_url  \
# 0                                                  0
# 1  http://www.census.gov/cps/data/cpstablecreator...
# 2                                                NaN
# 3  https://mwww.ba.ssa.gov/policy/docs/statcomps/...
# 4                                               null
#
#                             us_method_of_computation  \
# 0                                                  0
# 1  Please see http://www.census.gov/topics/income...
# 2                                                NaN
# 3  The U.S. Census Bureau provides the population...
# 4                                                NaN
#
#   disaggregation_categories disaggregation_geography date_metadata_updated  \
# 0                         0                        0                     0
# 1                       Sex                      Age         December 2016
# 2                       NaN                      NaN                   NaN
# 3                      None                     None         December 2016
# 4                      null                     null                  null
#
#   scheduled_update_by_SDG_team  \
# 0                            0
# 1               September 2017
# 2                          NaN
# 3                          NaN
# 4                         null
#
#                                      unit_of_measure  \
# 0                                                  0
# 1  Proportion of noninstitutionalized persons in ...
# 2                                                NaN
# 3                                            Persons
# 4                                               null
#
#   international_and_national_references graoh variable_unit_label
# 0                                     0     0                   0
# 1                                     0     0                   0
# 2                                     0     0                   0
# 3                                     0     0                   0
# 4                                     0     0                   0
#
# [5 rows x 46 columns]

# %%
df.to_csv(out_csv)
